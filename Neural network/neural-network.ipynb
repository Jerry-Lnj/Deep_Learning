# %%
import tensorflow as tf
import os
import pickle
import numpy as np

CIFAR_DIR = "./cifar-10-batches-py"
print(os.listdir(CIFAR_DIR))
# Out:
# ['data_batch_1', 'readme.html', 'batches.meta', 'data_batch_2', 'data_batch_5', 'test_batch', 'data_batch_4', 'data_batch_3']

# %%
def load_data(filename):
    """read data from data file"""
    with open(filename, "rb") as f:
        data = pickle.load(f, encoding='latin1')
        return data['data'], data['labels']
    
class CifarData:
    def __init__(self, filenames, need_shuffle):
        all_data = []
        all_labels = []
        for filename in filenames:
            data, labels = load_data(filename)
            all_data.append(data)
            all_labels.append(labels)
        self._data = np.vstack(all_data)
        self._data = self._data / 127.5 -1
        self._labels = np.hstack(all_labels)
        #print(self._data.shape)
        #print(self._labels.shape)
        self._num_examples = self._data.shape[0]
        self._need_shuffle = need_shuffle
        self._indicator = 0
        if self._need_shuffle:
            self._shuffle_data()
    
    def _shuffle_data(self):
        p = np.random.permutation(self._num_examples)
        self._data = self._data[p]
        self._labels = self._labels[p]
        
    def next_batch(self, batch_size):
        end_indicator = self._indicator + batch_size
        if end_indicator > self._num_examples:
            if self._need_shuffle:
                self._shuffle_data()
                self._indicator = 0
                end_indicator = batch_size
            else:
                raise Exception("have no more examples")
                    
        if end_indicator > self._num_examples:
            raise Exception("batch size is larger than all examples")
        batch_data = self._data[self._indicator: end_indicator]
        batch_labels = self._labels[self._indicator: end_indicator]
        self._indicator = end_indicator
        return batch_data, batch_labels
    
train_filenames = [os.path.join(CIFAR_DIR, 'data_batch_%d' %i) for i in range(1,6)]
test_filenames = [os.path.join(CIFAR_DIR, 'test_batch')]

train_data = CifarData(train_filenames, True)
test_data = CifarData(test_filenames, False)

#batch_data, batch_labels = train_data.next_batch(10)
#print(batch_data)
#print(batch_labels)

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

x = tf.compat.v1.placeholder(tf.float32, [None,3072])
y = tf.compat.v1.placeholder(tf.int64, [None])

hidden1 = tf.compat.v1.layers.dense(x, 100, activation = tf.nn.relu)
hidden2 = tf.compat.v1.layers.dense(hidden1, 100, activation = tf.nn.relu)
hidden3 = tf.compat.v1.layers.dense(hidden2, 50, activation = tf.nn.relu)
y_ = tf.compat.v1.layers.dense(hidden3, 10)

loss = tf.compat.v1.losses.sparse_softmax_cross_entropy(labels = y, logits= y_)

predict = tf.argmax(y_, 1)
correct_prediction = tf.equal(predict, y)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float64))

with tf.name_scope('train_op'):
    train_op = tf.compat.v1.train.AdamOptimizer(1e-3).minimize(loss)
# Out:
# /var/folders/n9/chhy6rnj2m3bh5gqhm0yjn6w0000gn/T/ipykernel_20177/4280068616.py:7: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   hidden1 = tf.compat.v1.layers.dense(x, 100, activation = tf.nn.relu)
# /var/folders/n9/chhy6rnj2m3bh5gqhm0yjn6w0000gn/T/ipykernel_20177/4280068616.py:8: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   hidden2 = tf.compat.v1.layers.dense(hidden1, 100, activation = tf.nn.relu)
# /var/folders/n9/chhy6rnj2m3bh5gqhm0yjn6w0000gn/T/ipykernel_20177/4280068616.py:9: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   hidden3 = tf.compat.v1.layers.dense(hidden2, 50, activation = tf.nn.relu)
# /var/folders/n9/chhy6rnj2m3bh5gqhm0yjn6w0000gn/T/ipykernel_20177/4280068616.py:10: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_ = tf.compat.v1.layers.dense(hidden3, 10)

# %%
init = tf.compat.v1.global_variables_initializer()
batch_size = 20
train_steps = 10000
test_steps = 100
with tf.compat.v1.Session() as sess:
    sess.run(init)
    for i in range(train_steps):
        batch_data, batch_labels = train_data.next_batch(batch_size)
        loss_val, acc_val, _ = sess.run([loss, accuracy, train_op], feed_dict={x:batch_data, y:batch_labels})
        if (i+1) %500 == 0:
            print ("[Train] Step: %d, loss: %4.5f, acc:%4.5f" %(i, loss_val, acc_val))
        if (i+1) %5000 ==0:
            test_data = CifarData(test_filenames, False)
            all_test_acc_val = []
            for j in range(test_steps):
                test_batch_data, test_batch_labels = test_data.next_batch(batch_size)
                test_acc_val = sess.run([accuracy],feed_dict = {x:test_batch_data,y:test_batch_labels})
                all_test_acc_val.append(test_acc_val)
                test_acc=np.mean(all_test_acc_val)
                print('[Test] Step: %d, acc: %4.5f' %(i+1, test_acc))
# Out:
# 2022-02-11 14:16:21.672177: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [Train] Step: 499, loss: 1.80404, acc:0.35000
# [Train] Step: 999, loss: 1.56157, acc:0.40000
# [Train] Step: 1499, loss: 1.92978, acc:0.25000
# [Train] Step: 1999, loss: 1.45369, acc:0.55000
# [Train] Step: 2499, loss: 1.40173, acc:0.35000
# [Train] Step: 2999, loss: 2.52297, acc:0.25000
# [Train] Step: 3499, loss: 1.56149, acc:0.40000
# [Train] Step: 3999, loss: 1.39957, acc:0.40000
# [Train] Step: 4499, loss: 1.88942, acc:0.35000
# [Train] Step: 4999, loss: 1.21042, acc:0.55000
# [Test] Step: 5000, acc: 0.65000
# [Test] Step: 5000, acc: 0.50000
# [Test] Step: 5000, acc: 0.46667
# [Test] Step: 5000, acc: 0.55000
# [Test] Step: 5000, acc: 0.57000
# [Test] Step: 5000, acc: 0.55000
# [Test] Step: 5000, acc: 0.53571
# [Test] Step: 5000, acc: 0.52500
# [Test] Step: 5000, acc: 0.50556
# [Test] Step: 5000, acc: 0.49500
# [Test] Step: 5000, acc: 0.47273
# [Test] Step: 5000, acc: 0.47917
# [Test] Step: 5000, acc: 0.46538
# [Test] Step: 5000, acc: 0.46786
# [Test] Step: 5000, acc: 0.47667
# [Test] Step: 5000, acc: 0.47813
# [Test] Step: 5000, acc: 0.47647
# [Test] Step: 5000, acc: 0.46944
# [Test] Step: 5000, acc: 0.46842
# [Test] Step: 5000, acc: 0.46750
# [Test] Step: 5000, acc: 0.46905
# [Test] Step: 5000, acc: 0.45909
# [Test] Step: 5000, acc: 0.46087
# [Test] Step: 5000, acc: 0.45625
# [Test] Step: 5000, acc: 0.45600
# [Test] Step: 5000, acc: 0.45192
# [Test] Step: 5000, acc: 0.44815
# [Test] Step: 5000, acc: 0.45357
# [Test] Step: 5000, acc: 0.45172
# [Test] Step: 5000, acc: 0.45333
# [Test] Step: 5000, acc: 0.45806
# [Test] Step: 5000, acc: 0.46250
# [Test] Step: 5000, acc: 0.46061
# [Test] Step: 5000, acc: 0.45735
# [Test] Step: 5000, acc: 0.46000
# [Test] Step: 5000, acc: 0.45556
# [Test] Step: 5000, acc: 0.45811
# [Test] Step: 5000, acc: 0.46316
# [Test] Step: 5000, acc: 0.46154
# [Test] Step: 5000, acc: 0.46000
# [Test] Step: 5000, acc: 0.45732
# [Test] Step: 5000, acc: 0.45595
# [Test] Step: 5000, acc: 0.46279
# [Test] Step: 5000, acc: 0.46932
# [Test] Step: 5000, acc: 0.47111
# [Test] Step: 5000, acc: 0.47174
# [Test] Step: 5000, acc: 0.46915
# [Test] Step: 5000, acc: 0.47083
# [Test] Step: 5000, acc: 0.47449
# [Test] Step: 5000, acc: 0.47500
# [Test] Step: 5000, acc: 0.47549
# [Test] Step: 5000, acc: 0.47692
# [Test] Step: 5000, acc: 0.47547
# [Test] Step: 5000, acc: 0.47963
# [Test] Step: 5000, acc: 0.48364
# [Test] Step: 5000, acc: 0.48661
# [Test] Step: 5000, acc: 0.48684
# [Test] Step: 5000, acc: 0.48879
# [Test] Step: 5000, acc: 0.48644
# [Test] Step: 5000, acc: 0.48833
# [Test] Step: 5000, acc: 0.49180
# [Test] Step: 5000, acc: 0.49113
# [Test] Step: 5000, acc: 0.49048
# [Test] Step: 5000, acc: 0.48984
# [Test] Step: 5000, acc: 0.48692
# [Test] Step: 5000, acc: 0.48712
# [Test] Step: 5000, acc: 0.48284
# [Test] Step: 5000, acc: 0.48235
# [Test] Step: 5000, acc: 0.48333
# [Test] Step: 5000, acc: 0.48071
# [Test] Step: 5000, acc: 0.48239
# [Test] Step: 5000, acc: 0.48264
# [Test] Step: 5000, acc: 0.48356
# [Test] Step: 5000, acc: 0.48649
# [Test] Step: 5000, acc: 0.48733
# [Test] Step: 5000, acc: 0.48816
# [Test] Step: 5000, acc: 0.48442
# [Test] Step: 5000, acc: 0.48397
# [Test] Step: 5000, acc: 0.48608
# [Test] Step: 5000, acc: 0.48250
# [Test] Step: 5000, acc: 0.48210
# [Test] Step: 5000, acc: 0.48171
# [Test] Step: 5000, acc: 0.48253
# [Test] Step: 5000, acc: 0.48571
# [Test] Step: 5000, acc: 0.48471
# [Test] Step: 5000, acc: 0.48547
# [Test] Step: 5000, acc: 0.48218
# [Test] Step: 5000, acc: 0.48352
# [Test] Step: 5000, acc: 0.48427
# [Test] Step: 5000, acc: 0.48556
# [Test] Step: 5000, acc: 0.48626
# [Test] Step: 5000, acc: 0.48587
# [Test] Step: 5000, acc: 0.48602
# [Test] Step: 5000, acc: 0.48670
# [Test] Step: 5000, acc: 0.48579
# [Test] Step: 5000, acc: 0.48333
# [Test] Step: 5000, acc: 0.48247
# [Test] Step: 5000, acc: 0.48316
# [Test] Step: 5000, acc: 0.48434
# [Test] Step: 5000, acc: 0.48350
# [Train] Step: 5499, loss: 1.18485, acc:0.55000
# [Train] Step: 5999, loss: 1.04336, acc:0.75000
# [Train] Step: 6499, loss: 1.24059, acc:0.65000
# [Train] Step: 6999, loss: 0.99411, acc:0.65000
# [Train] Step: 7499, loss: 1.38239, acc:0.45000
# [Train] Step: 7999, loss: 1.32128, acc:0.40000
# [Train] Step: 8499, loss: 1.27169, acc:0.70000
# [Train] Step: 8999, loss: 1.42600, acc:0.55000
# [Train] Step: 9499, loss: 1.19136, acc:0.50000
# [Train] Step: 9999, loss: 1.11941, acc:0.55000
# [Test] Step: 10000, acc: 0.55000
# [Test] Step: 10000, acc: 0.45000
# [Test] Step: 10000, acc: 0.43333
# [Test] Step: 10000, acc: 0.47500
# [Test] Step: 10000, acc: 0.51000
# [Test] Step: 10000, acc: 0.50833
# [Test] Step: 10000, acc: 0.52143
# [Test] Step: 10000, acc: 0.51250
# [Test] Step: 10000, acc: 0.51111
# [Test] Step: 10000, acc: 0.50000
# [Test] Step: 10000, acc: 0.48182
# [Test] Step: 10000, acc: 0.48333
# [Test] Step: 10000, acc: 0.46538
# [Test] Step: 10000, acc: 0.45714
# [Test] Step: 10000, acc: 0.46333
# [Test] Step: 10000, acc: 0.46250
# [Test] Step: 10000, acc: 0.46176
# [Test] Step: 10000, acc: 0.45556
# [Test] Step: 10000, acc: 0.45263
# [Test] Step: 10000, acc: 0.46250
# [Test] Step: 10000, acc: 0.46429
# [Test] Step: 10000, acc: 0.45227
# [Test] Step: 10000, acc: 0.45870
# [Test] Step: 10000, acc: 0.45417
# [Test] Step: 10000, acc: 0.46000
# [Test] Step: 10000, acc: 0.45577
# [Test] Step: 10000, acc: 0.45556
# [Test] Step: 10000, acc: 0.46250
# [Test] Step: 10000, acc: 0.46207
# [Test] Step: 10000, acc: 0.46500
# [Test] Step: 10000, acc: 0.47097
# [Test] Step: 10000, acc: 0.47188
# [Test] Step: 10000, acc: 0.47121
# [Test] Step: 10000, acc: 0.47206
# [Test] Step: 10000, acc: 0.47000
# [Test] Step: 10000, acc: 0.46806
# [Test] Step: 10000, acc: 0.47162
# [Test] Step: 10000, acc: 0.47105
# [Test] Step: 10000, acc: 0.46795
# [Test] Step: 10000, acc: 0.46750
# [Test] Step: 10000, acc: 0.46707
# [Test] Step: 10000, acc: 0.46429
# [Test] Step: 10000, acc: 0.46860
# [Test] Step: 10000, acc: 0.47045
# [Test] Step: 10000, acc: 0.47222
# [Test] Step: 10000, acc: 0.47391
# [Test] Step: 10000, acc: 0.47234
# [Test] Step: 10000, acc: 0.47500
# [Test] Step: 10000, acc: 0.47857
# [Test] Step: 10000, acc: 0.48000
# [Test] Step: 10000, acc: 0.48137
# [Test] Step: 10000, acc: 0.48269
# [Test] Step: 10000, acc: 0.47830
# [Test] Step: 10000, acc: 0.48148
# [Test] Step: 10000, acc: 0.48455
# [Test] Step: 10000, acc: 0.48929
# [Test] Step: 10000, acc: 0.49035
# [Test] Step: 10000, acc: 0.49052
# [Test] Step: 10000, acc: 0.48814
# [Test] Step: 10000, acc: 0.48917
# [Test] Step: 10000, acc: 0.48852
# [Test] Step: 10000, acc: 0.48871
# [Test] Step: 10000, acc: 0.48968
# [Test] Step: 10000, acc: 0.48828
# [Test] Step: 10000, acc: 0.48692
# [Test] Step: 10000, acc: 0.48788
# [Test] Step: 10000, acc: 0.48582
# [Test] Step: 10000, acc: 0.48676
# [Test] Step: 10000, acc: 0.48841
# [Test] Step: 10000, acc: 0.48714
# [Test] Step: 10000, acc: 0.48803
# [Test] Step: 10000, acc: 0.48958
# [Test] Step: 10000, acc: 0.48973
# [Test] Step: 10000, acc: 0.49122
# [Test] Step: 10000, acc: 0.49200
# [Test] Step: 10000, acc: 0.49145
# [Test] Step: 10000, acc: 0.48896
# [Test] Step: 10000, acc: 0.49359
# [Test] Step: 10000, acc: 0.49557
# [Test] Step: 10000, acc: 0.49313
# [Test] Step: 10000, acc: 0.49259
# [Test] Step: 10000, acc: 0.49329
# [Test] Step: 10000, acc: 0.49518
# [Test] Step: 10000, acc: 0.49643
# [Test] Step: 10000, acc: 0.49588
# [Test] Step: 10000, acc: 0.49651
# [Test] Step: 10000, acc: 0.49483
# [Test] Step: 10000, acc: 0.49545
# [Test] Step: 10000, acc: 0.49438
# [Test] Step: 10000, acc: 0.49333
# [Test] Step: 10000, acc: 0.49231
# [Test] Step: 10000, acc: 0.49239
# [Test] Step: 10000, acc: 0.49247
# [Test] Step: 10000, acc: 0.49149
# [Test] Step: 10000, acc: 0.49000
# [Test] Step: 10000, acc: 0.48958
# [Test] Step: 10000, acc: 0.48866
# [Test] Step: 10000, acc: 0.48878
# [Test] Step: 10000, acc: 0.48939
# [Test] Step: 10000, acc: 0.48900
